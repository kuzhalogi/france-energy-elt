# %% [markdown]
# # Energy Production eda

# %%
import pandas as pd
import numpy as np
import duckdb

# %%
con = duckdb.connect()

# load the table
def load_table(df, name):
    con.register(name, df)
    
# run the query
def run(query):
    return con.execute(query).df()

# %%
prod_filiere_path = '../Data/prod-region-annuelle-filiere.csv'
prod_enr_path = '../Data/prod-region-annuelle-enr.csv'

# %%
epr = pd.read_csv(prod_enr_path, sep=';')
epf = pd.read_csv(prod_filiere_path, sep=';')

# %%
epr.sample(10)
# Out:
#      Annee     Nom INSEE région  Code INSEE région  \
# 91    2010             Bretagne                 53
# 8     2013            Occitanie                 76
# 73    2021     Pays de la Loire                 52
# 92    2013  Centre-Val de Loire                 24
# 12    2008        Île-de-France                 11
# 118   2018     Pays de la Loire                 52
# 209   2014     Pays de la Loire                 52
# 109   2015             Bretagne                 53
# 85    2025                Corse                 94
# 35    2024   Nouvelle-Aquitaine                 75
#
#      Production hydraulique renouvelable (GWh)  \
# 91                                     540.100
# 8                                    11961.500
# 73                                      24.032
# 92                                     171.400
# 12                                      59.000
# 118                                     19.215
# 209                                     23.584
# ...

# %%
epr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 12 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Annee                                      234 non-null    int64
#  1   Nom INSEE région                           234 non-null    object
#  2   Code INSEE région                          234 non-null    int64
#  3   Production hydraulique renouvelable (GWh)  234 non-null    float64
#  4   Production bioénergies renouvelable (GWh)  233 non-null    float64
#  5   Production éolienne renouvelable (GWh)     231 non-null    float64
#  6   Production solaire renouvelable (GWh)      234 non-null    float64
#  7   Production électrique renouvelable (GWh)   234 non-null    float64
#  8   Production gaz renouvelable (GWh)          205 non-null    float64
#  9   Production totale renouvelable (GWh)       234 non-null    float64
# ...

# %%
epr.describe()
# Out:
#              Annee  Code INSEE région  \
# count   234.000000         234.000000
# mean   2016.500000          53.307692
# std       5.199249          27.350047
# min    2008.000000          11.000000
# 25%    2012.000000          28.000000
# 50%    2016.500000          52.000000
# 75%    2021.000000          76.000000
# max    2025.000000          94.000000
#
#        Production hydraulique renouvelable (GWh)  \
# count                                 234.000000
# mean                                 4461.215030
# std                                  7018.987965
# min                                     3.700000
# 25%                                    96.809250
# 50%                                   543.430000
# 75%                                  7864.445000
# max                                 30409.800000
#
#        Production bioénergies renouvelable (GWh)  \
# count                                 233.000000
# mean                                  477.932403
# ...

# %%
epr.columns
# Out:
# Index(['Annee', 'Nom INSEE région', 'Code INSEE région',
#        'Production hydraulique renouvelable (GWh)',
#        'Production bioénergies renouvelable (GWh)',
#        'Production éolienne renouvelable (GWh)',
#        'Production solaire renouvelable (GWh)',
#        'Production électrique renouvelable (GWh)',
#        'Production gaz renouvelable (GWh)',
#        'Production totale renouvelable (GWh)', 'Géo-shape région',
#        'Géo-point région'],
#       dtype='object')

# %%
regions_enr = epr['Nom INSEE région'].unique()
print(len(regions_enr))
regions_enr
# Out:
# 13
# array(['Centre-Val de Loire', 'Hauts-de-France', 'Grand Est',
#        'Auvergne-Rhône-Alpes', 'Bourgogne-Franche-Comté', 'Corse',
#        'Île-de-France', 'Occitanie', 'Nouvelle-Aquitaine', 'Bretagne',
#        'Pays de la Loire', "Provence-Alpes-Côte d'Azur", 'Normandie'],
#       dtype=object)

# %%
print(epr['Annee'].min())
print(epr['Annee'].max())
# Out:
# 2008
# 2025

# %%
epr.isnull().sum()
# Out:
# Annee                                         0
# Nom INSEE région                              0
# Code INSEE région                             0
# Production hydraulique renouvelable (GWh)     0
# Production bioénergies renouvelable (GWh)     1
# Production éolienne renouvelable (GWh)        3
# Production solaire renouvelable (GWh)         0
# Production électrique renouvelable (GWh)      0
# Production gaz renouvelable (GWh)            29
# Production totale renouvelable (GWh)          0
# Géo-shape région                              0
# Géo-point région                              0
# dtype: int64

# %% [markdown]
# ## Epf

# %%
epf.isnull().sum()
# Out:
# Année                             0
# Code INSEE région                 0
# Région                            0
# Production nucléaire (GWh)      108
# Production thermique (GWh)        0
# Production hydraulique (GWh)      0
# Production éolienne (GWh)         3
# Production solaire (GWh)          0
# Production bioénergies (GWh)      1
# Géo-shape région                  0
# Géo-point région                  0
# dtype: int64

# %%
epf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Année                         234 non-null    int64
#  1   Code INSEE région             234 non-null    int64
#  2   Région                        234 non-null    object
#  3   Production nucléaire (GWh)    126 non-null    float64
#  4   Production thermique (GWh)    234 non-null    float64
#  5   Production hydraulique (GWh)  234 non-null    float64
#  6   Production éolienne (GWh)     231 non-null    float64
#  7   Production solaire (GWh)      234 non-null    float64
#  8   Production bioénergies (GWh)  233 non-null    float64
#  9   Géo-shape région              234 non-null    object
#  10  Géo-point région              234 non-null    object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 20.2+ KB

# %%
epf.describe()
# Out:
#              Année  Code INSEE région  Production nucléaire (GWh)  \
# count   234.000000         234.000000                  126.000000
# mean   2016.500000          53.307692                54320.693651
# std       5.199249          27.350047                23928.507324
# min    2008.000000          11.000000                 4523.000000
# 25%    2012.000000          28.000000                35460.500000
# 50%    2016.500000          52.000000                58841.000000
# 75%    2021.000000          76.000000                76227.000000
# max    2025.000000          94.000000                90853.000000
#
#        Production thermique (GWh)  Production hydraulique (GWh)  \
# count                  234.000000                    234.000000
# mean                  3170.509829                   4830.717094
# std                   3227.293592                   7710.638117
# min                    149.000000                      3.700000
# ...

# %%
print(epf['Année'].min())
print(epf['Année'].max())
# Out:
# 2008
# 2025

# %%
epf['Région'].unique()
# Out:
# array(['Île-de-France', 'Centre-Val de Loire', 'Bourgogne-Franche-Comté',
#        'Normandie', 'Pays de la Loire', 'Nouvelle-Aquitaine',
#        "Provence-Alpes-Côte d'Azur", 'Hauts-de-France', 'Grand Est',
#        'Bretagne', 'Occitanie', 'Auvergne-Rhône-Alpes', 'Corse'],
#       dtype=object)

# %%
epf.isnull().sum()
# Out:
# Année                             0
# Code INSEE région                 0
# Région                            0
# Production nucléaire (GWh)      108
# Production thermique (GWh)        0
# Production hydraulique (GWh)      0
# Production éolienne (GWh)         3
# Production solaire (GWh)          0
# Production bioénergies (GWh)      1
# Géo-shape région                  0
# Géo-point région                  0
# dtype: int64
